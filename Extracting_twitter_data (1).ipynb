# %%
'''TWITTER CODE TEST_1 error--retweets
#!pip install TwitterSearch
from TwitterSearch import *
try:
    tso = TwitterSearchOrder() # create a TwitterSearchOrder object
    tso.set_keywords(['Dravid']) # let's define all words we would like to have a look for
    tso.set_language('en') # we want to see German tweets only
    tso.set_include_entities(True) # and don't give us all those entity information

    # it's about time to create a TwitterSearch object with our secret tokens
    ts = TwitterSearch(
        consumer_key = 'gsNZu76hJWPdWs3A0BTOkjwME',
        consumer_secret = 'xgEczLzJQgOnfOMUS3FAuXZZ67XZ7YHIFfm2r4xIP0Njx0bidg',
        access_token = '3224262668-eKAHOXMCnL0SIEVQtQDESfjqhOkB4DP9D19TbRe',
        access_token_secret = 'AoHdIbacX8YxNFNPCyIPqLeE8o6FN76JLyb6zTTvSHz10'
     )

     # this is where the fun actually starts :
    for tweet in ts.search_tweets_iterable(tso):
        print('@%s tweeted: %s' % ( tweet['user']['screen_name'], tweet['text']))
        
        
except TwitterSearchException as e: # take care of all those ugly errors if there are some
    print(e)
'''
# Out:
# "TWITTER CODE TEST_1 error--retweets\n#!pip install TwitterSearch\nfrom TwitterSearch import *\ntry:\n    tso = TwitterSearchOrder() # create a TwitterSearchOrder object\n    tso.set_keywords(['Dravid']) # let's define all words we would like to have a look for\n    tso.set_language('en') # we want to see German tweets only\n    tso.set_include_entities(True) # and don't give us all those entity information\n\n    # it's about time to create a TwitterSearch object with our secret tokens\n    ts = TwitterSearch(\n        consumer_key = 'gsNZu76hJWPdWs3A0BTOkjwME',\n        consumer_secret = 'xgEczLzJQgOnfOMUS3FAuXZZ67XZ7YHIFfm2r4xIP0Njx0bidg',\n        access_token = '3224262668-eKAHOXMCnL0SIEVQtQDESfjqhOkB4DP9D19TbRe',\n        access_token_secret = 'AoHdIbacX8YxNFNPCyIPqLeE8o6FN76JLyb6zTTvSHz10'\n     )\n\n     # this is where the fun actually starts :\n    for tweet in ts.search_tweets_iterable(tso):\n        print('@%s tweeted: %s' % ( tweet['user']['screen_name'], tweet['text']))
# ...

# %%
# !pip install tweepy==3.7.0
# Out:
# ...
#   Found existing installation: tweepy 3.6.0
#     Uninstalling tweepy-3.6.0:
#       Successfully uninstalled tweepy-3.6.0
# ...

# %%
import tweepy
import csv 
import os
import datetime
import sys

# Consumer keys and access tokens, used for OAuth
consumer_key = '*******************************'
consumer_secret = '*******************************'
access_token = '*******************************'
access_token_secret = '*******************************'

# OAuth process, using the keys and tokens
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

key = 'movie'
api = tweepy.API(auth,timeout=20)

list_tweets = []
#since=date_since
#date_since = "2018-11-16"
#for status in tweepy.Cursor(api.search, q = key+"-filter:retweets", lang = 'en', result_type = 'popular').items(1000):
 #list_tweets.append(status.text)list_tweets = []
  #since=date_since
  #date_since = "2018-11-16"

start_date = datetime.date(2018, 1, 13)
end_date   = datetime.date(2019, 1, 13)
for status in tweepy.Cursor(api.search, q = key+"-filter:retweets", lang = 'en', result_type = 'popular').items(100):
  list_tweets.append(status.text)

# %%
list_tweets
# Out:
# []

# %%
import tweepy
tweepy.__version__
# Out:
# '3.7.0'

# %%
len(list_tweets)
# Out:
# 100

# %%
import re
list_new = []

for tweet in list_tweets:
    tweet = re.sub(r"^https://t.co/[a-zA-Z0-9]*\s", " ", tweet)
    tweet = re.sub(r"\s+https://t.co/[a-zA-Z0-9]*\s", " ", tweet)
    tweet = re.sub(r"\s+https://t.co/[a-zA-Z0-9]*$", " ", tweet)
    tweet = tweet.lower()
    tweet = re.sub(r"that's","that is",tweet)
    tweet = re.sub(r"there's","there is",tweet)
    tweet = re.sub(r"what's","what is",tweet)
    tweet = re.sub(r"where's","where is",tweet)
    tweet = re.sub(r"it's","it is",tweet)
    tweet = re.sub(r"who's","who is",tweet)
    tweet = re.sub(r"i'm","i am",tweet)
    tweet = re.sub(r"she's","she is",tweet)
    tweet = re.sub(r"he's","he is",tweet)
    tweet = re.sub(r"they're","they are",tweet)
    tweet = re.sub(r"who're","who are",tweet)
    tweet = re.sub(r"ain't","am not",tweet)
    tweet = re.sub(r"wouldn't","would not",tweet)
    tweet = re.sub(r"shouldn't","should not",tweet)
    tweet = re.sub(r"can't","can not",tweet)
    tweet = re.sub(r"couldn't","could not",tweet)
    tweet = re.sub(r"won't","will not",tweet)
    tweet = re.sub(r"\W"," ",tweet)
    tweet = re.sub(r"\d"," ",tweet)
    tweet = re.sub(r"\s+[a-z]\s+"," ",tweet)
    tweet = re.sub(r"\s+[a-z]$"," ",tweet)
    tweet = re.sub(r"^[a-z]\s+"," ",tweet)
    tweet = re.sub(r"\s+"," ",tweet)

    #print(tweet,'\n')
    list_new.append(tweet)

# %%
list_new

# %%
#df = pd.Datarame(list_new)
#csv = df.to_csv('new_new.csv', index = False)

# %%
arr = []
for i in range(len(list_new)):
  a = vader(list_new[i])
  arr.append(a)

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# **Run from here**

# %%
# !pip install vadersentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
import tweepy
import csv #Import csv
import os
from google.colab import files

# Consumer keys and access tokens, used for OAuth
consumer_key = '*******************************'
consumer_secret = '*******************************'
access_token = '*******************************'
access_token_secret = '*******************************'

# OAuth process, using the keys and tokens
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# %%
def vader(text):
  analyzer = SentimentIntensityAnalyzer()
  sent = analyzer.polarity_scores(text)
  return sent

# %%
from textblob import TextBlob

# %%
def pol(text):
  t = TextBlob(text)
  ti = t.sentiment.polarity
  return ti

# %%
def sub(text):
  t = TextBlob(text)
  ti = t.sentiment.subjectivity
  return ti

# %%
import pandas as pd
df = pd.read_csv('IMDB_ratings_not_null.csv', header = 0)

# %%
df1 = df['Title']

# %%
import numpy as np

# %%
df1 = df1.values

# %%
def tweet(movie):
  key = movie
  api = tweepy.API(auth,wait_on_rate_limit = True)
  #print(key)

  list_tweets = []
  #since=date_since
  #date_since = "2018-11-16"
  for status in tweepy.Cursor(api.search, q = key+"-filter:retweets", lang = 'en', result_type = 'mixed').items(100):
    list_tweets.append(status.text)
    
    
  
  import re
  list_new = []

  for tweet in list_tweets:
      tweet = re.sub(r"^https://t.co/[a-zA-Z0-9]*\s", " ", tweet)
      tweet = re.sub(r"\s+https://t.co/[a-zA-Z0-9]*\s", " ", tweet)
      tweet = re.sub(r"\s+https://t.co/[a-zA-Z0-9]*$", " ", tweet)
      tweet = tweet.lower()
      tweet = re.sub(r"that's","that is",tweet)
      tweet = re.sub(r"there's","there is",tweet)
      tweet = re.sub(r"what's","what is",tweet)
      tweet = re.sub(r"where's","where is",tweet)
      tweet = re.sub(r"it's","it is",tweet)
      tweet = re.sub(r"who's","who is",tweet)
      tweet = re.sub(r"i'm","i am",tweet)
      tweet = re.sub(r"she's","she is",tweet)
      tweet = re.sub(r"he's","he is",tweet)
      tweet = re.sub(r"they're","they are",tweet)
      tweet = re.sub(r"who're","who are",tweet)
      tweet = re.sub(r"ain't","am not",tweet)
      tweet = re.sub(r"wouldn't","would not",tweet)
      tweet = re.sub(r"shouldn't","should not",tweet)
      tweet = re.sub(r"can't","can not",tweet)
      tweet = re.sub(r"couldn't","could not",tweet)
      tweet = re.sub(r"won't","will not",tweet)
      tweet = re.sub(r"\W"," ",tweet)
      tweet = re.sub(r"\d"," ",tweet)
      tweet = re.sub(r"\s+[a-z]\s+"," ",tweet)
      tweet = re.sub(r"\s+[a-z]$"," ",tweet)
      tweet = re.sub(r"^[a-z]\s+"," ",tweet)
      tweet = re.sub(r"\s+"," ",tweet)

      #print(tweet,'\n')
      list_new.append(tweet)
  #return(list_new)
      
  
  def vader_1(list_new):
    arr = []
    for i in range(len(list_new)):
      v = vader(list_new[i])
      arr.append(v)


    a = 0
    for i in range(len(arr)):
      a = a + arr[i]['compound']
    try: 
      a = (a/len(arr))#*33.3
      a = round(a,2)
      return(a)
    except ZeroDivisionError:
      return(0)
    
    
    
  
  def polar_1(list_new):
    arr = []
    for i in range(len(list_new)):
      v = pol(list_new[i])
      arr.append(v)


    a = 0
    for i in range(len(arr)):
      a = a + arr[i]
    try: 
      a = (a/len(arr))
      a = round(a,2)
      return(a)
    except ZeroDivisionError:
      return(0)
    
    
    
    
  def subject_1(list_new):
    arr = []
    for i in range(len(list_new)):
      v = sub(list_new[i])
      arr.append(v)


    a = 0
    for i in range(len(arr)):
      a = a + arr[i]
    try: 
      a = (a/len(arr))
      a = round(a,2)
      return(a)
    except ZeroDivisionError:
      return(0)
  
  v = vader_1(list_new)
  p = polar_1(list_new)
  s = subject_1(list_new)
  
  result = [v,p,s]
  return(result)

# %%
sentiment= []

for i in range(len(df1)):
  b = []
  b = tweet(df1[i])
  sentiment.append(b)
  print(i+410,b)
  
  
df = pd.DataFrame(sentiment)
df.to_csv('sentiment.csv')
files.download('sentiment.csv')
# Out:
# 410 [0.25, -0.11, 0.34]
# 411 [0.0, 0.0, 0.0]
# 412 [0.1, 0.11, 0.43]
# 413 [0.12, 0.06, 0.27]
# 414 [0.19, 0.06, 0.22]
# 415 [0.67, 0.0, 0.07]
# 416 [0, 0, 0]
# 417 [0.69, 0.65, 0.68]
# 418 [0.0, 0.0, 0.04]
# 419 [0.16, 0.14, 0.27]
# 420 [0.12, 0.15, 0.36]
# 421 [0.16, 0.05, 0.38]
# 422 [0.44, 0.4, 0.4]
# 423 [0, 0, 0]
# 424 [0.35, 0.33, 0.57]
# 425 [0.19, 0.18, 0.34]
# 426 [0.89, 0.82, 1.0]
# 427 [0.61, 0.39, 0.61]
# 428 [0.0, -0.18, 0.34]
# 429 [0.54, 0.41, 0.41]
# 430 [0.23, 0.22, 0.39]
# 431 [0.08, 0.08, 0.36]
# 432 [0, 0, 0]
# 433 [0.21, 0.13, 0.29]
# 434 [-0.45, -0.04, 0.41]
# 435 [0.19, 0.15, 0.29]
# 436 [0.2, 0.15, 0.27]
# 437 [0, 0, 0]
# 438 [0.14, 0.06, 0.41]
# 439 [0.02, 0.04, 0.27]
# 440 [0, 0, 0]
# 441 [0.2, 0.12, 0.39]
# 442 [-0.1, -0.03, 0.05]
# 443 [0, 0, 0]
# 444 [0.15, 0.13, 0.34]
# 445 [0.0, 0.0, 0.0]
# 446 [0, 0, 0]
# 447 [0.08, 0.07, 0.28]
# 448 [0.23, 0.32, 0.57]
# 449 [0.03, 0.05, 0.19]
# 450 [0.2, 0.11, 0.43]
# 451 [0.12, 0.07, 0.53]
# 452 [-0.38, 0.4, 0.4]
# ...

# %%
df = pd.DataFrame(sentiment)
df.to_csv('sentiment.csv')
files.download('sentiment.csv')

# %%
df_old = pd.read_csv('sentiment.csv',header = 0)

# %%
df_old.count()
# Out:
# Unnamed: 0    413
# 0             413
# 1             413
# 2             413
# dtype: int64

# %%
df_new = pd.read_csv('sentiment_1.csv', header = 0)

# %%
df_new.count()
# Out:
# Unnamed: 0    619
# 0             619
# 1             619
# 2             619
# dtype: int64

# %%
df_all_rows = pd.concat([df_old, df_new])

# %%
df_all_rows.count()
# Out:
# Unnamed: 0    1032
# 0             1032
# 1             1032
# 2             1032
# dtype: int64

# %%
df_all_rows.to_csv('Semi_Final_sentiment.csv')

# %%
tweet(df1[412])
# Out:
# [0.09, 0.14, 0.42]

# %%
a
# Out:
# [0.17, 0.07, 0.28]

# %%
len(df1)
# Out:
# 1029

# %%
final = pd.read_csv('Final.csv',)

# %%
# Out:
# 0        1028
# 0.1      1028
# 0.44     1028
# -0.08    1028
# 0.23     1028
# dtype: int64

# %%
final = final.reset_index(drop=True)

# %%
final.to_csv('Final.csv')

# %%
final.head()

# %%
final.tail()

# %%
f = pd.read_csv('Final.csv')

# %%
tweet('Kabir Singh')

# %%
a
# Out:
# [0.18, 0.11, 0.34]

# %%
f.count()
# Out:
# Vader      1029
# Polar      1029
# Subject    1029
# dtype: int64

# %%
g = pd.read_csv('Imdb_genre_gnews.csv')

# %%
f3 = f['Subject']

# %%
f3 = f3.values

# %%
g['Subject'] = f3

# %%
g.head()
# Out:
#    Unnamed: 0                            Title  IMDB  ...  Vader  Polar  Subject
# 0           0                   Dulha Mil Gaya   4.4  ...   0.44  -0.08     0.23
# 1           1                Pyaar Impossible!   4.7  ...  -0.03  -0.50     0.84
# 2           2                  Chance Pe Dance   4.7  ...   0.14   0.04     0.20
# 3           3  Hello! Hum Lallan Bol Rahe Hain   6.3  ...   0.00   0.00     0.00
# 4           4                 The Waiting Room   6.5  ...  -0.01   0.02     0.33
#
# [5 rows x 8 columns]

# %%
g.tail()
# Out:
#       Unnamed: 0          Title  IMDB  G_news  Genre  Vader  Polar  Subject
# 1024        1024         Bharat   5.9    0.50      2   0.03   0.04     0.34
# 1025        1025    Kabir Singh   8.5    0.60      2   0.22   0.15     0.34
# 1026        1026          Drive   7.3    0.50      6   0.06   0.07     0.37
# 1027        1027     Dream Girl   6.5    0.50      3   0.33   0.09     0.35
# 1028        1028  Street Dancer   5.7    0.55      4   0.04   0.06     0.25

# %%
g = g.drop('Unnamed: 0', axis = 1)

# %%
g.head()
# Out:
#                              Title  IMDB  G_news  Genre  Vader  Polar  Subject
# 0                   Dulha Mil Gaya   4.4    0.60      3   0.44  -0.08     0.23
# 1                Pyaar Impossible!   4.7    0.45      3  -0.03  -0.50     0.84
# 2                  Chance Pe Dance   4.7    0.65      3   0.14   0.04     0.20
# 3  Hello! Hum Lallan Bol Rahe Hain   6.3    0.55      3   0.00   0.00     0.00
# 4                 The Waiting Room   6.5    0.40     11  -0.01   0.02     0.33

# %%
g = g[['Title','Genre','G_news','Vader','Polar','Subject','IMDB']]

# %%
g.head()
# Out:
#                              Title  Genre  G_news  Vader  Polar  Subject  IMDB
# 0                   Dulha Mil Gaya      3    0.60   0.44  -0.08     0.23   4.4
# 1                Pyaar Impossible!      3    0.45  -0.03  -0.50     0.84   4.7
# 2                  Chance Pe Dance      3    0.65   0.14   0.04     0.20   4.7
# 3  Hello! Hum Lallan Bol Rahe Hain      3    0.55   0.00   0.00     0.00   6.3
# 4                 The Waiting Room     11    0.40  -0.01   0.02     0.33   6.5

# %%
g.to_csv('FINAL_DATASET.csv')
